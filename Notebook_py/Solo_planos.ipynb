# %%
# librerias

# !pip install pandas openpyxl -q
# !pip install folium -q
# !pip install geopy -q
# !pip install opencage -q
# !pip install scikit-learn -q
# !pip install matplotlib -q
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import warnings
import folium
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn.metrics.pairwise import haversine_distances
from sklearn.cluster import DBSCAN
from sklearn.metrics.pairwise import haversine_distances
import matplotlib.colors as mcolors
from matplotlib import colormaps
import math


warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl")

# %%
df = pd.read_excel("data/Reporte Histórico de Roturas - Surtigas.xlsx", sheet_name="Detalle Roturas Historico")
df.rename(columns={"LAT ": "LAT"}, inplace=True)
df_plano = df.dropna(subset=["LAT", "LONG"])

# %%
# Centro del mapa (promedio de coordenadas)
mapa = folium.Map(location=[df_plano.LAT.mean(), df_plano.LONG.mean()], zoom_start=8)

for i, row in df_plano.iterrows():
    folium.CircleMarker(
        location=[row.LAT, row.LONG],
        radius=2,                    # tamaño
        color="blue",                # borde
        fill=True,
        fill_color="blue",           # relleno
        fill_opacity=0.7,
        popup=f"Punto {i+1}<br>({row.LAT}, {row.LONG})",
        tooltip=f"Punto {i+1}"
    ).add_to(mapa)


mapa.save("mapa1.html")
mapa  # renderiza inline en Jupyter
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a0044030a678a08e85e7476622272f62 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a0044030a678a08e85e7476622272f62&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a0044030a678a08e85e7476622272f62 = L.map(
#                 &quot;map_a0044030a678a08e85e7476622272f62&quot;,
#                 {
#                     center: [9.5473004168, -75.36403730077333],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9b834ab5fe7956959594f23b120a33e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d9b834ab5fe7956959594f23b120a33e.addTo(map_a0044030a678a08e85e7476622272f62);
#
#
#             var circle_marker_fb50c2ba91239fea00c7b9241d32a76c = L.circleMarker(
#                 [10.42666, -75.51678],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a0044030a678a08e85e7476622272f62);
#
#
#         var popup_857d0111896b67ea2d9c7a1f3f31df96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84d7bb7c1e3e5617204b3c495a714037 = $(`&lt;div id=&quot;html_84d7bb7c1e3e5617204b3c495a714037&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto 8595&lt;br&gt;(10.42666, -75.51678)&lt;/div&gt;`)[0];
#                 popup_857d0111896b67ea2d9c7a1f3f31df96.setContent(html_84d7bb7c1e3e5617204b3c495a714037);
#
#
#
#         circle_marker_fb50c2ba91239fea00c7b9241d32a76c.bindPopup(popup_857d0111896b67ea2d9c7a1f3f31df96)
#         ;
#
#
#
#
#             circle_marker_fb50c2ba91239fea00c7b9241d32a76c.bindTooltip(
#                 `&lt;div&gt;
#                      Punto 8595
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_f3bb4008cecc8a6ab8184a759b9ebde2 = L.circleMarker(
#                 [9.53423, -75.22321],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a0044030a678a08e85e7476622272f62);
#
#
#         var popup_3eb4af595d8ff72c9fffe11b82e23c21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4abf329ca9208300119b9a252e356418 = $(`&lt;div id=&quot;html_4abf329ca9208300119b9a252e356418&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto 8596&lt;br&gt;(9.53423, -75.22321)&lt;/div&gt;`)[0];
#                 popup_3eb4af595d8ff72c9fffe11b82e23c21.setContent(html_4abf329ca9208300119b9a252e356418);
#
#
#
#         circle_marker_f3bb4008cecc8a6ab8184a759b9ebde2.bindPopup(popup_3eb4af595d8ff72c9fffe11b82e23c21)
#         ;
#
#
#
#
#             circle_marker_f3bb4008cecc8a6ab8184a759b9ebde2.bindTooltip(
#                 `&lt;div&gt;
#                      Punto 8596
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_6b284c45659fe3ec03b2218968115167 = L.circleMarker(
#                 [8.72326, -75.88196],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a0044030a678a08e85e7476622272f62);
#
#
#         var popup_a2b993d433f224905d3741eb7ff1faf1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });

# %%
# ── Parámetros DBSCAN ────────────────────────────────────────────────────────
RADIO_KM    = 0.400   # ← distancia máxima entre vecinos (en km). Ajusta según tu escala
MIN_PUNTOS  = 5     # ← mínimo de puntos para formar un cluster (no ruido)

# ── 1. DBSCAN sobre coordenadas en radianes ──────────────────────────────────
coords_rad = np.radians(df_plano[["LAT", "LONG"]].values)

db = DBSCAN(
    eps=RADIO_KM / 6371.0,   # convertir km → radianes
    min_samples=MIN_PUNTOS,
    algorithm="ball_tree",
    metric="haversine"
).fit(coords_rad)

df_plano["cluster"] = db.labels_          # -1 = ruido (puntos aislados)

n_clusters  = df_plano["cluster"].max() + 1
n_ruido     = (df_plano["cluster"] == -1).sum()
print(f"✅ Clusters encontrados: {n_clusters}  |  Puntos ignorados (ruido): {n_ruido}")

# ── 2. Construir el mapa ─────────────────────────────────────────────────────
mapa = folium.Map(
    location=[df_plano.LAT.mean(), df_plano.LONG.mean()],
    zoom_start=12,
    tiles="CartoDB positron"
)

# ── 3. Dibujar un círculo translúcido por cluster ────────────────────────────
for cid in range(n_clusters):
    grupo = df_plano[df_plano["cluster"] == cid]
    n     = len(grupo)

    centro_lat = grupo.LAT.mean()
    centro_lon = grupo.LONG.mean()

    # Radio = distancia haversine máxima desde el centroide (en metros)
    puntos_rad = np.radians(grupo[["LAT", "LONG"]].values)
    centro_rad = np.radians([[centro_lat, centro_lon]])
    dists_m    = haversine_distances(puntos_rad, centro_rad)[:, 0] * 6371000
    radio_m    = max(dists_m.max() * 1.15, 300)   # +15% margen, mínimo 300 m

    # Color según densidad
    if n > 20:
        color = "#e74c3c"     # rojo
    elif n > 10:
        color = "#e67e22"     # naranja
    else:
        color = "#f1c40f"     # amarillo

    # Círculo principal translúcido
    folium.Circle(
        location=[centro_lat, centro_lon],
        radius=radio_m,
        color=color,
        weight=2.5,
        fill=True,
        fill_color=color,
        fill_opacity=0.20,
        popup=folium.Popup(
            f"<b>Zona {cid + 1}</b><br>"
            f"Puntos: {n}<br>"
            f"Radio: {radio_m:.0f} m<br>"
            f"Centro: ({centro_lat:.4f}, {centro_lon:.4f})",
            max_width=200
        ),
        tooltip=f"🔴 Zona {cid+1} · {n} puntos"
    ).add_to(mapa)

    # Borde punteado interior para resaltar el contorno
    folium.Circle(
        location=[centro_lat, centro_lon],
        radius=radio_m,
        color=color,
        weight=1,
        fill=False,
        dash_array="6 4",
    ).add_to(mapa)

    # Punto central
    folium.CircleMarker(
        location=[centro_lat, centro_lon],
        radius=5,
        color="white",
        weight=1.5,
        fill=True,
        fill_color=color,
        fill_opacity=1.0,
        tooltip=f"Centroide zona {cid+1}"
    ).add_to(mapa)

# ── 4. Puntos originales (azul = dentro de cluster, gris = ruido) ─────────────
for _, row in df_plano.iterrows():
    es_ruido = row["cluster"] == -1
    folium.CircleMarker(
        location=[row.LAT, row.LONG],
        radius=2,
        color="#7f8c8d" if es_ruido else "#2980b9",
        fill=True,
        fill_color="#bdc3c7" if es_ruido else "#3498db",
        fill_opacity=0.6 if es_ruido else 0.85,
        tooltip="Punto aislado" if es_ruido else f"Zona {int(row['cluster']) + 1}"
    ).add_to(mapa)

mapa.save("mapa2.html")
mapa
# Out:
# ✅ Clusters encontrados: 35  |  Puntos ignorados (ruido): 472
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5994d2e8575ba6f3ed4ed1855781823e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5994d2e8575ba6f3ed4ed1855781823e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5994d2e8575ba6f3ed4ed1855781823e = L.map(
#                 &quot;map_5994d2e8575ba6f3ed4ed1855781823e&quot;,
#                 {
#                     center: [9.5473004168, -75.36403730077333],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c554051be888871fe16485335b05fff9 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c554051be888871fe16485335b05fff9.addTo(map_5994d2e8575ba6f3ed4ed1855781823e);
#
#
#             var circle_8cafeb0212edf6e158fcf65b8c7ec32d = L.circle(
#                 [10.428291999999999, -75.51800399999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f1c40f&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f1c40f&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_5994d2e8575ba6f3ed4ed1855781823e);
#
#
#         var popup_43990e9c3b361010b71455e6a650e9bc = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_9f03ea523f898fe2622226d7178d8b5b = $(`&lt;div id=&quot;html_9f03ea523f898fe2622226d7178d8b5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Zona 1&lt;/b&gt;&lt;br&gt;Puntos: 5&lt;br&gt;Radio: 300 m&lt;br&gt;Centro: (10.4283, -75.5180)&lt;/div&gt;`)[0];
#                 popup_43990e9c3b361010b71455e6a650e9bc.setContent(html_9f03ea523f898fe2622226d7178d8b5b);
#
#
#
#         circle_8cafeb0212edf6e158fcf65b8c7ec32d.bindPopup(popup_43990e9c3b361010b71455e6a650e9bc)
#         ;
#
#
#
#
#             circle_8cafeb0212edf6e158fcf65b8c7ec32d.bindTooltip(
#                 `&lt;div&gt;
#                      🔴 Zona 1 · 5 puntos
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_f6c7702d92b10e5a00c1c0d1e72350a3 = L.circle(
#                 [10.428291999999999, -75.51800399999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f1c40f&quot;, &quot;dashArray&quot;: &quot;6 4&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#f1c40f&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_5994d2e8575ba6f3ed4ed1855781823e);
#
#
#             var circle_marker_b7a73699f811ee5513e84b0d0fce444c = L.circleMarker(
#                 [10.428291999999999, -75.51800399999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;white&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f1c40f&quot;, &quot;fillOpacity&quot;: 1.0, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 1.5}
#             ).addTo(map_5994d2e8575ba6f3ed4ed1855781823e);
#
#
#             circle_marker_b7a73699f811ee5513e84b0d0fce444c.bindTooltip(
#                 `&lt;div&gt;
#                      Centroide zona 1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_1196cbef657c041217a06a212016719e = L.circle(
#                 [9.726125714285715, -75.13190714285714],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f1c40f&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f1c40f&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;r

# %% [markdown]
# # Limpieza da datos

# %%
df_plano["Dimensión Rotura"] = df_plano["Dimensión Rotura"].replace("Minimo", "Mínimo")
df_plano["Dimensión Rotura"] = df_plano["Dimensión Rotura"].fillna("NO APLICA")

# %%
from fractions import Fraction

def diametro_a_numero(valor):
    valor = str(valor).strip()
    
    try:
        # caso: "1 1/2"
        if " " in valor:
            entero, fraccion = valor.split()
            return float(entero) + float(Fraction(fraccion))
        
        # caso: "1/2"
        if "/" in valor:
            return float(Fraction(valor))
        
        # caso: número normal "2", "3"
        return float(valor)
    
    except:
        return None

# %%
df_plano["Diametro"] = df["Diametro"].astype(str)
df_plano["Diametro"] = df_plano["Diametro"].replace("2026-04-03 00:00:00", "3/4")
df_plano["Diametro_num"] = df_plano["Diametro"].apply(diametro_a_numero)

# %%
df_plano["Orgen_data"] = str("Probado")

# %%
import json

with open("mapeo_categorias.json", "r", encoding="utf-8") as f:
    data = json.load(f)

mapeo = data["mapeo"]

# %%
df_plano["categoria_final"] = df_plano["TIPO"].map(mapeo)

# %%
import branca

def agregar_leyenda(mapa, beta, n_clusters, score_min, score_max):
    """
    Agrega una leyenda flotante al mapa Folium con:
    - Escala de colores YlOrRd
    - Parámetros actuales (β, clusters encontrados)
    - Referencia de opacidad
    """
    # ── Genera la barra de color en HTML usando matplotlib ────────────────
    import matplotlib.pyplot as plt
    import matplotlib.colors as mcolors
    import numpy as np
    import base64
    from io import BytesIO

    fig, ax = plt.subplots(figsize=(3, 0.35))
    fig.patch.set_alpha(0)
    cmap = plt.cm.get_cmap("YlOrRd")
    norm = mcolors.Normalize(vmin=0, vmax=1)
    cb   = plt.colorbar(
        plt.cm.ScalarMappable(norm=norm, cmap=cmap),
        cax=ax, orientation="horizontal"
    )
    cb.set_ticks([0, 0.25, 0.5, 0.75, 1.0])
    cb.set_ticklabels(["0.0\nBajo", "0.25", "0.50", "0.75", "1.0\nAlto"])
    cb.ax.tick_params(labelsize=7, colors="#333")
    plt.tight_layout(pad=0.1)

    # Convierte la figura a base64 para embeber en HTML
    buf = BytesIO()
    plt.savefig(buf, format="png", dpi=120, bbox_inches="tight",
                transparent=True)
    plt.close()
    buf.seek(0)
    img_b64 = base64.b64encode(buf.read()).decode("utf-8")

    # ── HTML de la leyenda ────────────────────────────────────────────────
    legend_html = f"""
    <div style="
        position: fixed;
        bottom: 40px; right: 15px;
        z-index: 1000;
        background: rgba(255,255,255,0.05);
        border: 1px solid #ccc;
        border-radius: 8px;
        padding: 10px 14px;
        font-family: Arial, sans-serif;
        font-size: 12px;
        color: #333;
        box-shadow: 2px 2px 6px rgba(0,0,0,0.2);
        min-width: 200px;
    ">
        <b style="font-size:13px;">🗺️ Score Final</b>
        <hr style="margin:5px 0; border-color:#ddd;">

        <!-- Barra de color -->
        <img src="data:image/png;base64,{img_b64}"
             style="width:100%; margin: 4px 0;">

        <!-- Parámetros -->
        <div style="margin-top:6px; line-height:1.7;">
            <b>β</b> = {beta}
            &nbsp;·&nbsp;
            <span style="color:#888">
                {round(beta*100)}% variables + {round((1-beta)*100)}% densidad
            </span><br>
            <b>Clusters</b>: {n_clusters}<br>
            <b>Rango score</b>: [{score_min:.2f} – {score_max:.2f}]
        </div>

        <!-- Referencia de opacidad -->
        <hr style="margin:6px 0; border-color:#ddd;">
        <div style="font-size:11px; color:#666;">
            Opacidad del círculo = intensidad del score
        </div>
        <div style="display:flex; gap:4px; margin-top:4px; align-items:center;">
            <div style="width:28px;height:14px;background:#e74c3c;
                        opacity:0.15;border:1px solid #e74c3c;
                        border-radius:3px;"></div>
            <span style="font-size:10px;">Bajo</span>
            <div style="width:28px;height:14px;background:#e74c3c;
                        opacity:0.5;border:1px solid #e74c3c;
                        border-radius:3px; margin-left:8px;"></div>
            <span style="font-size:10px;">Medio</span>
            <div style="width:28px;height:14px;background:#e74c3c;
                        opacity:0.85;border:1px solid #e74c3c;
                        border-radius:3px; margin-left:8px;"></div>
            <span style="font-size:10px;">Alto</span>
        </div>
    </div>
    """
    mapa.get_root().html.add_child(folium.Element(legend_html))
    return mapa

# %%
# ══════════════════════════════════════════════════════════════════════════════
# 0. PARÁMETROS GLOBALES — modifica aquí libremente
# ══════════════════════════════════════════════════════════════════════════════
BETA        = 0.5    # 0 = solo densidad | 1 = solo variables | 0.5 = equilibrio
RADIO_KM    = 0.5    # vecindad DBSCAN en km
MIN_PUNTOS  = 5      # mínimo de puntos para formar cluster

# ── Dimensión Rotura: Total y NO APLICA con igual peso máximo ─────────────────
# Total     = rotura completa          → máxima gravedad
# NO APLICA = evento sin rotura física → igual de relevante operativamente
# Parcial   = daño intermedio
# Mínima    = daño superficial
MAP_DIM_ROTURA = {
    "Total":     1.00,
    "NO APLICA": 1.00,
    "Parcial":   0.50,
    "Mínima":    0.15,
}

# ── TERCERO/OBRA: TERCERO es 1.5× más relevante que OBRA ─────────────────────
# Normalizando sobre el máximo (1.5): OBRA = 0.667, TERCERO = 1.0
_max_to = 1.5
MAP_TERCERO_OBRA = {
    "OBRA":    round(1.0 / _max_to, 4),   # ≈ 0.6667
    "TERCERO": round(1.5 / _max_to, 4),   # = 1.0000
}

# ── TIPO: severidad descendente (posición 1 = más grave) ─────────────────────
_tipos_ordenados = [
    "Excavación",                              # 1.000
    "Alcantarillado y acueducto",              # 0.667
    "Pavimentación",                           # 0.889
    "Instalaciones ",                          # 0.778
    "Obras civiles y construcción",            # 0.556
    "Limpieza",                                # 0.444
    "Daños",                                   # 0.333
    "Instalación de tuberías y ductos eléctricos", # 0.222
    "Nivelación de terreno y calles",          # 0.111
    "Otros",                                   # 0.000
]
n_t = len(_tipos_ordenados)
MAP_TIPO = {
    tipo: round(1.0 - i / (n_t - 1), 4)
    for i, tipo in enumerate(_tipos_ordenados)
}

# ── Probado / Inferido: confianza del dato ────────────────────────────────────
MAP_CERTEZA = {
    "Probado":  1.00,
    "Inferido": 0.20,
}

# ══════════════════════════════════════════════════════════════════════════════
# 2. PESOS DE CADA VARIABLE EN EL SCORE DEL PUNTO   (deben sumar 1.0)
# ══════════════════════════════════════════════════════════════════════════════
PESOS = {
    "diametro":    0.25,
    "dim_rotura":  0.25,
    "tercero_obra":0.25,
    "tipo":        0.25,
}
assert abs(sum(PESOS.values()) - 1.0) < 1e-9, "⚠️ Los pesos deben sumar 1.0"

# ══════════════════════════════════════════════════════════════════════════════
# 3. SCORE POR PUNTO
# ══════════════════════════════════════════════════════════════════════════════
def calcular_score_punto(row):
    """
    Recibe una fila del DataFrame y devuelve un score en [0, 1].
    Ajusta los nombres de columna según tu DataFrame real.
    """
    s_diam  = row.get("Diametro_num", 0.0)
    s_rot   = MAP_DIM_ROTURA .get(str(row["Dimensión Rotura"]),    0.0)
    s_to    = MAP_TERCERO_OBRA.get(str(row["TERCERO/OBRA PUBLICA"]), 0.0)
    s_tipo  = MAP_TIPO       .get(str(row["categoria_final"]),         0.0)
    s_cert  = MAP_CERTEZA    .get(str(row["Orgen_data"]),      0.0)

    return (
        s_cert * (PESOS["diametro"] * s_diam  +
        PESOS["dim_rotura"] * s_rot   +
        PESOS["tercero_obra"] * s_to    +
        PESOS["tipo"] * s_tipo)
    )

df_plano["score_punto"] = df_plano.apply(calcular_score_punto, axis=1)

# ══════════════════════════════════════════════════════════════════════════════
# 4. DBSCAN — detección de clusters geográficos
# ══════════════════════════════════════════════════════════════════════════════
coords_rad = np.radians(df_plano[["LAT", "LONG"]].values)

db = DBSCAN(
    eps=RADIO_KM / 6371.0,
    min_samples=MIN_PUNTOS,
    algorithm="ball_tree",
    metric="haversine"
).fit(coords_rad)

df_plano["cluster"] = db.labels_
n_clusters = df_plano["cluster"].max() + 1
n_ruido    = (df_plano["cluster"] == -1).sum()
print(f"✅ Clusters: {n_clusters}  |  Ruido: {n_ruido} puntos")

# ══════════════════════════════════════════════════════════════════════════════
# 5. SCORE POR CLUSTER
# ══════════════════════════════════════════════════════════════════════════════
max_puntos = df_plano[df_plano["cluster"] >= 0].groupby("cluster").size().max()

resumen_clusters = []
for cid in range(n_clusters):
    grupo = df_plano[df_plano["cluster"] == cid]
    n     = len(grupo)

    centro_lat = grupo.LAT.mean()
    centro_lon = grupo.LONG.mean()
    ciudad = grupo.Ciudad.unique()[0]

    # Radio geográfico real (huella física)
    puntos_rad = np.radians(grupo[["LAT", "LONG"]].values)
    centro_rad = np.radians([[centro_lat, centro_lon]])
    dists_m    = haversine_distances(puntos_rad, centro_rad)[:, 0] * 6371000
    radio_m    = max(dists_m.max() * 1.15, 300)   # +15% margen, mín 300 m

    # Score de variables: promedio del cluster (independiente del tamaño)
    score_vars    = grupo["score_punto"].mean()

    # Score de densidad: n relativo al cluster más denso
    score_densidad = n / max_puntos

    # Score final ponderado por β
    score_final = BETA * score_vars + (1 - BETA) * score_densidad

    resumen_clusters.append({
        "cid":        cid,
        "n":          n,
        "Ciudad":     ciudad,
        "lat":        centro_lat,
        "lon":        centro_lon,
        "radio_m":    radio_m,
        "score_vars": score_vars,
        "score_dens": score_densidad,
        "score_final":score_final,
    })

df_clusters = pd.DataFrame(resumen_clusters)

# ══════════════════════════════════════════════════════════════════════════════
# 6. COLORMAP continuo YlOrRd  →  score_final [0,1] a color hex
# ══════════════════════════════════════════════════════════════════════════════
cmap = colormaps["YlOrRd"]

def score_a_color(score):
    r, g, b, _ = cmap(float(score))
    return mcolors.to_hex((r, g, b))

def score_a_opacidad(score, op_min=0.15, op_max=0.75):
    """La opacidad del relleno respira con el score_final."""
    return op_min + (op_max - op_min) * float(score)

# ══════════════════════════════════════════════════════════════════════════════
# 7. MAPA FOLIUM
# ══════════════════════════════════════════════════════════════════════════════
mapa = folium.Map(
    location=[df_plano.LAT.mean(), df_plano.LONG.mean()],
    tiles="CartoDB positron",
    zoom_start=12
)

# ── Círculos de clusters ───────────────────────────────────────────────────
for _, c in df_clusters.iterrows():
    color   = score_a_color(c.score_final)
    opacidad = score_a_opacidad(c.score_final)

    # Círculo translúcido principal
    folium.Circle(
        location=[c.lat, c.lon],
        radius=c.radio_m,
        color=color,
        weight=2.5,
        fill=True,
        fill_color=color,
        fill_opacity=opacidad,
        popup=folium.Popup(
            f"<b>Zona {int(c.cid)+1}</b><br>"
            f"Puntos: {int(c.n)}<br>"
            f"Score variables: {c.score_vars:.3f}<br>"
            f"Score densidad: {c.score_dens:.3f}<br>"
            f"<b>Score final (β={BETA}): {c.score_final:.3f}</b><br>"
            f"Radio: {c.radio_m:.0f} m<br>"
            f"Área: {math.pi * (c.radio_m/1000)**2:.1f} km2",
            max_width=220
        ),
        tooltip=f"Zona {int(c.cid)+1} · score {c.score_final:.2f} · {int(c.n)} pts"
    ).add_to(mapa)

    # Borde punteado interior
    folium.Circle(
        location=[c.lat, c.lon],
        radius=c.radio_m,
        color=color,
        weight=1,
        fill=False,
        dash_array="6 4",
    ).add_to(mapa)

    # Centroide
    folium.CircleMarker(
        location=[c.lat, c.lon],
        radius=5,
        color="white",
        weight=1.5,
        fill=True,
        fill_color=color,
        fill_opacity=1.0,
        tooltip=f"Centroide zona {int(c.cid)+1}"
    ).add_to(mapa)

# ── Puntos individuales ────────────────────────────────────────────────────
for _, row in df_plano.iterrows():
    es_ruido = row["cluster"] == -1
    pt_color = score_a_color(row["score_punto"]) if not es_ruido else "#7f8c8d"
    folium.CircleMarker(
        location=[row.LAT, row.LONG],
        radius=3,
        color="white",
        weight=0.5,
        fill=True,
        fill_color=pt_color,
        fill_opacity=0.85 if not es_ruido else 0.4,
        tooltip=(
            f"Zona {int(row['cluster'])+1} · score {row['score_punto']:.2f}"
            if not es_ruido else "Punto aislado"
        )
    ).add_to(mapa)

# ── Úsala así, justo antes de mostrar el mapa ────────────────────────────────
mapa = agregar_leyenda(
    mapa,
    beta       = BETA,
    n_clusters = n_clusters,
    score_min  = df_clusters["score_final"].min(),
    score_max  = df_clusters["score_final"].max(),
)

mapa.save("mapa3.html")
mapa
# Out:
# ✅ Clusters: 38  |  Ruido: 407 puntos
# /tmp/ipykernel_9632/80531385.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("YlOrRd")
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f939f87d8ddbbd0be60c4f747a7e6207 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed;
#         bottom: 40px; right: 15px;
#         z-index: 1000;
#         background: rgba(255,255,255,0.05);
#         border: 1px solid #ccc;
#         border-radius: 8px;
#         padding: 10px 14px;
#         font-family: Arial, sans-serif;
#         font-size: 12px;
#         color: #333;
#         box-shadow: 2px 2px 6px rgba(0,0,0,0.2);
#         min-width: 200px;
#     &quot;&gt;
#         &lt;b style=&quot;font-size:13px;&quot;&gt;🗺️ Score Final&lt;/b&gt;
#         &lt;hr style=&quot;margin:5px 0; border-color:#ddd;&quot;&gt;
#
#         &lt;!-- Barra de color --&gt;
#         &lt;img src=&quot;data:image/png;base64,...&quot;
#              style=&quot;width:100%; margin: 4px 0;&quot;&gt;
#
#         &lt;!-- Parámetros --&gt;
#         &lt;div style=&quot;margin-top:6px; line-height:1.7;&quot;&gt;
#             &lt;b&gt;β&lt;/b&gt; = 0.5
#             &amp;nbsp;·&amp;nbsp;
#             &lt;span style=&quot;color:#888&quot;&gt;
#                 50% variables + 50% densidad
#             &lt;/span&gt;&lt;br&gt;
#             &lt;b&gt;Clusters&lt;/b&gt;: 38&lt;br&gt;
#             &lt;b&gt;Rango score&lt;/b&gt;: [0.24 – 0.76]
#         &lt;/div&gt;
#
#         &lt;!-- Referencia de opacidad --&gt;
#         &lt;hr style=&quot;margin:6px 0; border-color:#ddd;&quot;&gt;
#         &lt;div style=&quot;font-size:11px; color:#666;&quot;&gt;
#             Opacidad del círculo = intensidad del score
#         &lt;/div&gt;
#         &lt;div style=&quot;display:flex; gap:4px; margin-top:4px; align-items:center;&quot;&gt;
#             &lt;div style=&quot;width:28px;height:14px;background:#e74c3c;
#                         opacity:0.15;border:1px solid #e74c3c;
#                         border-radius:3px;&quot;&gt;&lt;/div&gt;
#             &lt;span style=&quot;font-size:10px;&quot;&gt;Bajo&lt;/span&gt;
#             &lt;div style=&quot;width:28px;height:14px;background:#e74c3c;
#                         opacity:0.5;border:1px solid #e74c3c;
#                         border-radius:3px; margin-left:8px;&quot;&gt;&lt;/div&gt;
#             &lt;span style=&quot;font-size:10px;&quot;&gt;Medio&lt;/span&gt;
#             &lt;div style=&quot;width:28px;height:14px;background:#e74c3c;
#                         opacity:0.85;border:1px solid #e74c3c;
#                         border-radius:3px; margin-left:8px;&quot;&gt;&lt;/div&gt;
#             &lt;span style=&quot;font-size:10px;&quot;&gt;Alto&lt;/span&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f939f87d8ddbbd0be60c4f747a7e6207&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f939f87d8ddbbd0be60c4f747a7e6207 = L.map(
#                 &quot;map_f939f87d8ddbbd0be60c4f747a7e6207&quot;,
#                 {
#                     center: [9.5473004168, -75.36403730077333],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc38db778e6a7d8be41836ab8bdeb386 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bc38db778e6a7d8be41836ab8bdeb386.addTo(map_f939f87d8ddbbd0be60c4f747a7e6207);
#
#
#             var circle_191fa3cfcd3eb0b5abc29bfa24c27887 = L.circle(
#                 [10.429183333333333, -75.517375],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fec15d&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fec15d&quot;, &quot;fillOpacity&quot;: 0.34638875, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 693.6941181272127, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_f939f87d8ddbbd0be60c4f747a7e6207);
#
#
#         var popup_7213e6591b41fbec8bce4fc30aabc8da = L.popup({
#   &quot;maxWidth&quot;: 220,
# });
#
#
#
#                 var html_ef1d7830e3190c22b1792c6967f14446 = $(`&lt;div id=&quot;html_ef1d7830e3190c22b1792c6967f14446&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Zona 1&lt;/b&gt;&lt;br&gt;Puntos: 6&lt;br&gt;Score variables: 0.505&lt;br&gt;Score densidad: 0.150&lt;br&gt;&lt;b&gt;Score final (β=0.5): 0.327&lt;/b&gt;&lt;br&gt;Radio: 694 m&lt;br&gt;Área: 1.5 km2&lt;/div&gt;`)[0];
#                 popup_7213e6591b41fbec8bce4fc30aabc8da.setContent(html_ef1d7830e3190c22b1792c6967f

# %%
#df_clusters.sort_values(by='score_final', ascending=False)

# %% [markdown]
# ## Limpieza dataframe inferido (df_final)

# %%
df_final = pd.read_csv("df_final.csv")
df_final = df_final.drop(columns=["Unnamed: 0"])

# %%
from fractions import Fraction

def diametro_a_numero(valor):
    valor = str(valor).strip()
    
    try:
        # caso: "1 1/2"
        if " " in valor:
            entero, fraccion = valor.split()
            return float(entero) + float(Fraction(fraccion))
        
        # caso: "1/2"
        if "/" in valor:
            return float(Fraction(valor))
        
        # caso: número normal "2", "3"
        return float(valor)
    
    except:
        return None

# %%
with open("mapeo_categorias.json", "r", encoding="utf-8") as f:
    config = json.load(f)

# Extraer el diccionario de mapeo
mapeo = config["mapeo"]

# %%
df_final["Dimensión Rotura"] = df_final["Dimensión Rotura"].replace("Minimo", "Mínimo")
df_final["Dimensión Rotura"] = df_final["Dimensión Rotura"].fillna("NO APLICA")


df_final["Diametro"] = df["Diametro"].astype(str)
df_final["Diametro"] = df_final["Diametro"].replace("2026-04-03 00:00:00", "3/4")
df_final["Diametro_num"] = df_final["Diametro"].apply(diametro_a_numero)

df_final["Orgen_data"] = str("Inferido")

df_final["categoria_final"] = df_final["TIPO"].map(mapeo)

# %%
df_final = df_final.rename(columns={"lat": "LAT", "lon": "LONG"})

# %%
df_final = df_final.dropna()

# %%
df_inf = df_final[['Ciudad', 'Diametro', 'Dimensión Rotura', 'TERCERO/OBRA PUBLICA',
       'TIPO', 'LAT', 'LONG', 'Orgen_data', 'Diametro_num',
       'categoria_final']]

# %%
df_real = df_plano[['Ciudad', 'Diametro', 'Dimensión Rotura', 'TERCERO/OBRA PUBLICA',
       'TIPO', 'LAT', 'LONG', 'Orgen_data', 'Diametro_num',
       'categoria_final']]

# %%
df_dev = pd.concat([df_real, df_inf], ignore_index=True)

# %%
df_dev.Orgen_data.value_counts()
# Out:
# Orgen_data
# Inferido    6909
# Probado      750
# Name: count, dtype: int64

# %%
import folium
import numpy as np
import pandas as pd
from sklearn.cluster import DBSCAN
from sklearn.metrics.pairwise import haversine_distances
import matplotlib.colors as mcolors
from matplotlib import colormaps
import math

# ══════════════════════════════════════════════════════════════════════════════
# 0. PARÁMETROS GLOBALES — modifica aquí libremente
# ══════════════════════════════════════════════════════════════════════════════
BETA        = 0.5    # 0 = solo densidad | 1 = solo variables | 0.5 = equilibrio
RADIO_KM    = 0.2    # vecindad DBSCAN en km
MIN_PUNTOS  = 10      # mínimo de puntos para formar cluster

# ── Dimensión Rotura: Total y NO APLICA con igual peso máximo ─────────────────
# Total     = rotura completa          → máxima gravedad
# NO APLICA = evento sin rotura física → igual de relevante operativamente
# Parcial   = daño intermedio
# Mínima    = daño superficial
MAP_DIM_ROTURA = {
    "Total":     1.00,
    "NO APLICA": 1.00,
    "Parcial":   0.50,
    "Mínima":    0.15,
}

# ── TERCERO/OBRA: TERCERO es 1.5× más relevante que OBRA ─────────────────────
# Normalizando sobre el máximo (1.5): OBRA = 0.667, TERCERO = 1.0
_max_to = 1.5
MAP_TERCERO_OBRA = {
    "OBRA":    round(1.0 / _max_to, 4),   # ≈ 0.6667
    "TERCERO": round(1.5 / _max_to, 4),   # = 1.0000
}

# ── TIPO: severidad descendente (posición 1 = más grave) ─────────────────────
_tipos_ordenados = [
    "Excavación",                              # 1.000
    "Alcantarillado y acueducto",              # 0.667
    "Pavimentación",                           # 0.889
    "Instalaciones ",                          # 0.778
    "Obras civiles y construcción",            # 0.556
    "Limpieza",                                # 0.444
    "Daños",                                   # 0.333
    "Instalación de tuberías y ductos eléctricos", # 0.222
    "Nivelación de terreno y calles",          # 0.111
    "Otros",                                   # 0.000
]
n_t = len(_tipos_ordenados)
MAP_TIPO = {
    tipo: round(1.0 - i / (n_t - 1), 4)
    for i, tipo in enumerate(_tipos_ordenados)
}

# ── Probado / Inferido: confianza del dato ────────────────────────────────────
MAP_CERTEZA = {
    "Probado":  1.00,
    "Inferido": 0.20,
}

# ══════════════════════════════════════════════════════════════════════════════
# 2. PESOS DE CADA VARIABLE EN EL SCORE DEL PUNTO   (deben sumar 1.0)
# ══════════════════════════════════════════════════════════════════════════════
PESOS = {
    "diametro":    0.25,
    "dim_rotura":  0.25,
    "tercero_obra":0.25,
    "tipo":        0.25,
}
assert abs(sum(PESOS.values()) - 1.0) < 1e-9, "⚠️ Los pesos deben sumar 1.0"

# ══════════════════════════════════════════════════════════════════════════════
# 3. SCORE POR PUNTO
# ══════════════════════════════════════════════════════════════════════════════
def calcular_score_punto(row):
    """
    Recibe una fila del DataFrame y devuelve un score en [0, 1].
    Ajusta los nombres de columna según tu DataFrame real.
    """
    s_diam  = row.get("Diametro_num", 0.0)
    s_rot   = MAP_DIM_ROTURA .get(str(row["Dimensión Rotura"]),    0.0)
    s_to    = MAP_TERCERO_OBRA.get(str(row["TERCERO/OBRA PUBLICA"]), 0.0)
    s_tipo  = MAP_TIPO       .get(str(row["categoria_final"]),         0.0)
    s_cert  = MAP_CERTEZA    .get(str(row["Orgen_data"]),      0.0)

    return (
        s_cert * (PESOS["diametro"] * s_diam  +
        PESOS["dim_rotura"] * s_rot   +
        PESOS["tercero_obra"] * s_to    +
        PESOS["tipo"] * s_tipo)
    )

df_dev["score_punto"] = df_dev.apply(calcular_score_punto, axis=1)

# ══════════════════════════════════════════════════════════════════════════════
# 4. DBSCAN — detección de clusters geográficos
# ══════════════════════════════════════════════════════════════════════════════
coords_rad = np.radians(df_dev[["LAT", "LONG"]].values)

db = DBSCAN(
    eps=RADIO_KM / 6371.0,
    min_samples=MIN_PUNTOS,
    algorithm="ball_tree",
    metric="haversine"
).fit(coords_rad)

df_dev["cluster"] = db.labels_
n_clusters = df_dev["cluster"].max() + 1
n_ruido    = (df_dev["cluster"] == -1).sum()
print(f"✅ Clusters: {n_clusters}  |  Ruido: {n_ruido} puntos")

# ══════════════════════════════════════════════════════════════════════════════
# 5. SCORE POR CLUSTER
# ══════════════════════════════════════════════════════════════════════════════
max_puntos = df_dev[df_dev["cluster"] >= 0].groupby("cluster").size().max()

resumen_clusters = []
for cid in range(n_clusters):
    grupo = df_dev[df_dev["cluster"] == cid]
    n     = len(grupo)

    centro_lat = grupo.LAT.mean()
    centro_lon = grupo.LONG.mean()
    ciudad = grupo.Ciudad.unique()[0]

    # Radio geográfico real (huella física)
    puntos_rad = np.radians(grupo[["LAT", "LONG"]].values)
    centro_rad = np.radians([[centro_lat, centro_lon]])
    dists_m    = haversine_distances(puntos_rad, centro_rad)[:, 0] * 6371000
    radio_m    = max(dists_m.max() * 1.15, 300)   # +15% margen, mín 300 m

    # Score de variables: promedio del cluster (independiente del tamaño)
    score_vars    = grupo["score_punto"].mean()

    # Score de densidad: n relativo al cluster más denso
    score_densidad = n / max_puntos

    # Score final ponderado por β
    score_final = BETA * score_vars + (1 - BETA) * score_densidad

    resumen_clusters.append({
        "cid":        cid,
        "n":          n,
        "Ciudad":     ciudad,
        "lat":        centro_lat,
        "lon":        centro_lon,
        "radio_m":    radio_m,
        "score_vars": score_vars,
        "score_dens": score_densidad,
        "score_final":score_final,
    })

df_clusters = pd.DataFrame(resumen_clusters)

# ══════════════════════════════════════════════════════════════════════════════
# 6. COLORMAP continuo YlOrRd  →  score_final [0,1] a color hex
# ══════════════════════════════════════════════════════════════════════════════
cmap = colormaps["YlOrRd"]

def score_a_color(score):
    r, g, b, _ = cmap(float(score))
    return mcolors.to_hex((r, g, b))

def score_a_opacidad(score, op_min=0.15, op_max=0.75):
    """La opacidad del relleno respira con el score_final."""
    return op_min + (op_max - op_min) * float(score)

# ══════════════════════════════════════════════════════════════════════════════
# 7. MAPA FOLIUM
# ══════════════════════════════════════════════════════════════════════════════
mapa = folium.Map(
    location=[df_plano.LAT.mean(), df_plano.LONG.mean()],
    tiles="CartoDB positron",
    zoom_start=12
)

# ── Círculos de clusters ───────────────────────────────────────────────────
for _, c in df_clusters.iterrows():
    color   = score_a_color(c.score_final)
    opacidad = score_a_opacidad(c.score_final)

    # Círculo translúcido principal
    folium.Circle(
        location=[c.lat, c.lon],
        radius=c.radio_m,
        color=color,
        weight=2.5,
        fill=True,
        fill_color=color,
        fill_opacity=opacidad,
        popup=folium.Popup(
            f"<b>Zona {int(c.cid)+1}</b><br>"
            f"Puntos: {int(c.n)}<br>"
            f"Score variables: {c.score_vars:.3f}<br>"
            f"Score densidad: {c.score_dens:.3f}<br>"
            f"<b>Score final (β={BETA}): {c.score_final:.3f}</b><br>"
            f"Radio: {c.radio_m:.0f} m<br>"
            f"Área: {math.pi * (c.radio_m/1000)**2:.1f} km2",
            max_width=220
        ),
        tooltip=f"Zona {int(c.cid)+1} · score {c.score_final:.2f} · {int(c.n)} pts"
    ).add_to(mapa)

    # Borde punteado interior
    folium.Circle(
        location=[c.lat, c.lon],
        radius=c.radio_m,
        color=color,
        weight=1,
        fill=False,
        dash_array="6 4",
    ).add_to(mapa)

    # Centroide
    folium.CircleMarker(
        location=[c.lat, c.lon],
        radius=5,
        color="white",
        weight=1.5,
        fill=True,
        fill_color=color,
        fill_opacity=1.0,
        tooltip=f"Centroide zona {int(c.cid)+1}"
    ).add_to(mapa)

# ── Puntos individuales ────────────────────────────────────────────────────
for _, row in df_dev.iterrows():
    es_ruido = row["cluster"] == -1
    pt_color = score_a_color(row["score_punto"]) if not es_ruido else "#7f8c8d"
    folium.CircleMarker(
        location=[row.LAT, row.LONG],
        radius=3,
        color="white",
        weight=0.5,
        fill=True,
        fill_color=pt_color,
        fill_opacity=0.85 if not es_ruido else 0.4,
        tooltip=(
            f"Zona {int(row['cluster'])+1} · score {row['score_punto']:.2f}"
            if not es_ruido else "Punto aislado"
        )
    ).add_to(mapa)

# ── Úsala así, justo antes de mostrar el mapa ────────────────────────────────
mapa = agregar_leyenda(
    mapa,
    beta       = BETA,
    n_clusters = n_clusters,
    score_min  = df_clusters["score_final"].min(),
    score_max  = df_clusters["score_final"].max(),
)

mapa.save("mapa4.html")
#mapa
# Out:
# ✅ Clusters: 158  |  Ruido: 4479 puntos
# /tmp/ipykernel_9632/80531385.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("YlOrRd")
